# %%
import os
import _pickle as cPickle
import numpy as np
from scipy.io.wavfile import read
from featureextraction import extract_features
#from speakerfeatures import extract_features
import warnings
warnings.filterwarnings("ignore")
import time
"""
#path to training data
source   = "development_set/"   
modelpath = "speaker_models/"
test_file = "development_set_test.txt"        
file_paths = open(test_file,'r')
"""
#path to training data
source   = "SampleData/"   
#path where training speakers will be saved
modelpath = "Speakers_models/"
gmm_files = [os.path.join(modelpath,fname) for fname in os.listdir(modelpath) if fname.endswith('.gmm')]
#Load the Gaussian gender Models
models = [cPickle.load(open(fname,'rb')) for fname in gmm_files]
speakers = [fname.split("/")[-1].split(".gmm")[0] for fname in gmm_files]
error = 0
total_sample = 0.0
print ("Do you want to Test a Single Audio: Press '1' or The complete Test Audio Sample: Press '0' ?")
take = int(input())
if take==1:
        try:
                print("Enter the File name from Test Audio Sample Collection :")
                path = input()
                print("Testing Audio",path)
                sr,audio=read(source + path)
                vector = extract_features(audio,sr)
                log_likelihood = np.zeros(len(models))
                for i in range(len(models)):
                        gmm= models[i]  #checking with each model one by one
                        print("GMM Is:",gmm)
                        scores = np.array(gmm.score(vector))
                        print("Scores is :",scores)
                        log_likelihood[i] = scores.sum()
                        print("Lof Likelihod is :",log_likelihood)
                winner = np.argmax(log_likelihood) # return max elementof the array in a particular axis
                print ("\tdetected as - ", speakers[winner])
                time.sleep(1.0)
        except Exception as e:
                print(e)
if take == 0:
        try:
                
                test_file = "testSamplePath.txt"        
                file_paths = open(test_file,'r')
                # Read the test directory and get the list of test audio files 
                for path in file_paths:
                        total_sample += 1.0
                        path = path.strip()
                        print ("Testing Audio : ", path)
                        sr,audio = read(source + path)
                        vector   = extract_features(audio,sr)
                        print("vector is :",vector)
                        log_likelihood = np.zeros(len(models))
                        print("log_likelihood is :",log_likelihood )
                        for i in range(len(models)):
                                gmm    = models[i]  #checking with each model one by one
                                scores = np.array(gmm.score(vector))
                                log_likelihood[i] = scores.sum()
                                print(" particular log_likelihood is :",log_likelihood )
                                
                        winner = np.argmax(log_likelihood)
                        print("\tdetected as - ", speakers[winner])
                        checker_name = path.split("_")[0]
                        if speakers[winner] != checker_name:
                                error += 1
                        time.sleep(1.0)
                print (error, total_sample)
            
        except Exception as e:
                print(e)
print (" Mission Accomplished Successfully. ")
# Out:
# Do you want to Test a Single Audio: Press '1' or The complete Test Audio Sample: Press '0' ?
# 0
# Testing Audio :  navneet_test1.wav
# vector is : [[-1.31706195 -0.65497825  0.2696416  ...  0.01321142 -0.03581372
#   -0.22849064]
#  [-1.27948276 -0.44136963  0.50896887 ... -0.10840044 -0.2380219
#   -0.49142891]
#  [-1.15665249 -0.42960972  0.38209551 ... -0.25736717 -0.27751811
#   -0.36132725]
#  ...
#  [-1.67584325 -1.0852879   0.19575241 ...  0.24895006  0.37235635
#    0.25177254]
#  [-1.65668517 -0.91466463  0.44441211 ...  0.24833227  0.31037987
#    0.18685079]
#  [-1.74078406 -0.97892536  0.57527591 ...  0.01390491  0.06963091
#    0.08577415]]
# log_likelihood is : [0. 0. 0. 0. 0.]
#  particular log_likelihood is : [-24.70241039   0.           0.           0.           0.        ]
#  particular log_likelihood is : [-24.70241039 -17.65249805   0.           0.           0.        ]
#  particular log_likelihood is : [-24.70241039 -17.65249805 -23.31693682   0.           0.        ]
#  particular log_likelihood is : [-24.70241039 -17.65249805 -23.31693682 -23.89243566   0.        ]
#  particular log_likelihood is : [-24.70241039 -17.65249805 -23.31693682 -23.89243566 -24.37379592]
# 	detected as -  navneet
# Testing Audio :  navneet_test2.wav
# vector is : [[-8.50813199e-01 -7.34390810e-01  2.06693885e-02 ... -1.64281091e-01
#   -1.22866243e-01 -1.40278598e-01]
#  [-9.57323167e-01 -7.63865722e-01 -9.95992825e-02 ... -2.32612013e-01
#   -2.26278114e-02  1.30435471e-02]
#  [-1.19301027e+00 -6.50455920e-01  2.90153675e-01 ... -3.11613989e-01
#    1.42099775e-03 -4.50768511e-03]
#  ...
#  [-1.69885903e+00 -1.52502152e+00  2.50221079e-01 ...  1.84074382e-01
#   -1.76192677e-02 -1.55649884e-01]
#  [-1.67159484e+00 -1.26156568e+00  5.00911398e-01 ...  1.58241146e-02
#   -1.79128332e-01 -2.93718869e-01]
#  [-1.93840177e+00 -1.21787464e+00  5.11347860e-01 ... -2.87341406e-02
#   -1.68098781e-01 -1.88157530e-01]]
# log_likelihood is : [0. 0. 0. 0. 0.]
#  particular log_likelihood is : [-24.18453116   0.           0.           0.           0.        ]
#  particular log_likelihood is : [-24.18453116 -18.19200427   0.           0.           0.        ]
#  particular log_likelihood is : [-24.18453116 -18.19200427 -25.97260032   0.           0.        ]
#  particular log_likelihood is : [-24.18453116 -18.19200427 -25.97260032 -23.7669046    0.        ]
#  particular log_likelihood is : [-24.18453116 -18.19200427 -25.97260032 -23.7669046  -24.70915777]
# 	detected as -  navneet
# Testing Audio :  shubham_test1.wav
# vector is : [[ 2.01129379 -1.58403225 -0.78553242 ... -0.12974645 -0.25962341
#    0.28406167]
#  [ 1.39241576 -0.65249514 -1.86716307 ... -0.16899042 -0.17189015
#    0.3221004 ]
#  [ 1.42908779 -0.64635354 -1.82858951 ... -0.08568457  0.08111055
#    0.20377608]
#  ...
#  [-1.36558108 -0.8207218   0.85192027 ...  0.0567955  -0.00969655
#   -0.0616542 ]
#  [-1.36441652 -0.86285263  0.77020202 ... -0.22280648 -0.29154746
#   -0.3915214 ]
#  [-1.38826901 -0.85254162  0.69441317 ... -0.27974719 -0.29036186
#   -0.35649924]]
# log_likelihood is : [0. 0. 0. 0. 0.]
#  particular log_likelihood is : [-22.42925993   0.           0.           0.           0.        ]
#  particular log_likelihood is : [-22.42925993 -21.92068972   0.           0.           0.        ]
#  particular log_likelihood is : [-22.42925993 -21.92068972 -25.76814762   0.           0.        ]
#  particular log_likelihood is : [-22.42925993 -21.92068972 -25.76814762 -14.51505226   0.        ]
#  particular log_likelihood is : [-22.42925993 -21.92068972 -25.76814762 -14.51505226 -22.24192852]
# 	detected as -  shubham
# Testing Audio :  shubham_test2.wav
# vector is : [[ 2.43291952 -0.97056468 -0.79034377 ...  0.21802974  0.01246352
#    0.01401386]
#  [-1.04557468 -0.93288867 -0.35414808 ...  0.32141997  0.1879751
#    0.15329687]
#  [-1.07797037 -1.01460973 -0.6140781  ...  0.29827662  0.09584957
#    0.04202854]
#  ...
#  [-1.33681614 -0.63691733  0.03107109 ... -0.42519818  0.16706908
#    0.44500755]
#  [-1.33727679 -0.51383514  0.20495997 ... -0.38107116  0.3214292
#    0.70182465]
#  [-1.52770111 -0.4677108   0.13295567 ... -0.15368056  0.28855998
#    0.48582012]]
# log_likelihood is : [0. 0. 0. 0. 0.]
#  particular log_likelihood is : [-25.37586269   0.           0.           0.           0.        ]
#  particular log_likelihood is : [-25.37586269 -26.1537496    0.           0.           0.        ]
#  particular log_likelihood is : [-25.37586269 -26.1537496  -28.44646507   0.           0.        ]
#  particular log_likelihood is : [-25.37586269 -26.1537496  -28.44646507 -22.41515531   0.        ]
#  particular log_likelihood is : [-25.37586269 -26.1537496  -28.44646507 -22.41515531 -26.76863159]
# 	detected as -  shubham
# Testing Audio :  jatin sir_test1.wav
# vector is : [[ 1.28156185 -1.46048063 -1.27858109 ... -0.33635745 -0.20368726
#   -0.19044048]
#  [ 1.48359302 -2.16971963 -1.14731544 ... -0.31420097 -0.05495653
#   -0.04586431]
#  [ 1.19995762 -1.69002942 -1.86807781 ... -0.08452     0.14878234
#    0.02260747]
#  ...
#  [-0.71989766 -2.13970118 -0.94990765 ...  0.13821763 -0.1640931
#   -0.10548831]
#  [-0.40246324 -2.20905412 -0.97608754 ...  0.01912986 -0.31187097
#   -0.16432766]
#  [-0.50999089 -2.19953159 -0.85229896 ...  0.02580098 -0.21784416
#   -0.11274336]]
# log_likelihood is : [0. 0. 0. 0. 0.]
#  particular log_likelihood is : [-21.57357051   0.           0.           0.           0.        ]
#  particular log_likelihood is : [-21.57357051 -24.99593541   0.           0.           0.        ]
#  particular log_likelihood is : [-21.57357051 -24.99593541 -25.11374675   0.           0.        ]
#  particular log_likelihood is : [-21.57357051 -24.99593541 -25.11374675 -23.91280949   0.        ]
#  particular log_likelihood is : [-21.57357051 -24.99593541 -25.11374675 -23.91280949 -24.33229892]
# 	detected as -  jatinsir
# Testing Audio :  sparsh sir_test1.wav
# vector is : [[-0.31730221 -0.74880919 -0.27507642 ... -0.01902216 -0.19142653
#    0.00293309]
#  [-1.52514054 -0.76598947  0.04438205 ... -0.01879393 -0.33079565
#    0.1084077 ]
#  [-1.32993527 -0.90582996  0.18282767 ... -0.04369971 -0.34870034
#    0.2257032 ]
#  ...
#  [-1.43408957 -0.97389302 -0.81251537 ... -0.08266413 -0.3063816
#    0.02754901]
#  [-1.41432627 -0.91410838 -0.86742039 ... -0.17085506 -0.17373273
#    0.09726741]
#  [-1.4256596  -0.88921858 -0.9082529  ... -0.09475465  0.03184241
#    0.17023039]]
# log_likelihood is : [0. 0. 0. 0. 0.]
#  particular log_likelihood is : [-24.13812098   0.           0.           0.           0.        ]
#  particular log_likelihood is : [-24.13812098 -26.01839698   0.           0.           0.        ]
#  particular log_likelihood is : [-24.13812098 -26.01839698 -26.01350475   0.           0.        ]
#  particular log_likelihood is : [-24.13812098 -26.01839698 -26.01350475 -24.50019036   0.        ]
#  particular log_likelihood is : [-24.13812098 -26.01839698 -26.01350475 -24.50019036 -22.41132173]
# 	detected as -  sparshsir
# Testing Audio :  sachin sir_test1.wav
# vector is : [[-0.0435735  -0.20179419 -0.15152135 ... -0.00911374 -0.04972797
#   -0.37831557]
#  [-1.10062883 -0.45879489  0.78070971 ... -0.16935567  0.01117662
#   -0.08079204]
#  [-0.70647027 -1.17643329  0.89682882 ... -0.26412835  0.10695029
#    0.3396778 ]
#  ...
#  [-1.31730855 -0.71716949 -0.51857233 ... -0.0473345  -0.12067836
#   -0.24685843]
#  [-1.31457709 -0.65791312 -0.48238548 ... -0.2840935  -0.55625491
#   -0.34067301]
#  [-1.29002906 -0.61999953 -0.39782034 ... -0.13908872 -0.48151673
#   -0.14557576]]
# log_likelihood is : [0. 0. 0. 0. 0.]
#  particular log_likelihood is : [-24.01166126   0.           0.           0.           0.        ]
#  particular log_likelihood is : [-24.01166126 -23.993769     0.           0.           0.        ]
#  particular log_likelihood is : [-24.01166126 -23.993769   -21.88338764   0.           0.        ]
#  particular log_likelihood is : [-24.01166126 -23.993769   -21.88338764 -24.17333863   0.        ]
#  particular log_likelihood is : [-24.01166126 -23.993769   -21.88338764 -24.17333863 -23.26471682]
# 	detected as -  sachinsir
# 3 7.0
#  Mission Accomplished Successfully.
